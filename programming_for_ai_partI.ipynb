# %% [markdown]
# <a href="https://colab.research.google.com/github/hernanescorp/master_AI_notes/blob/main/programming_for_ai_partI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROGRAMMING FOR AI**

# %% [markdown]
# ## **PART 1**: *Standart AI programming*

# %% [markdown]
# ### JUPYTERLAB NOTEBOOKS

# %% [markdown]
# iPython/Jupyter Commands

# %%
# !ls # Listar archivos y carpetas
# Out:
# sample_data

# %%
# !pwd #Ruta donde te encuentras
# Out:
# /content

# %%
history #History of commands
# Out:
# ?keyword
# history
# !ls
# !pwd
# history

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
variable = 1
print(variable)
# Out:
# 1

# %%
# %xdel variable
print(variable)
# Out:
# NameError: name 'variable' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2467/1126501036.py in <cell line: 0>()
#       1 get_ipython().run_line_magic('xdel', 'variable')
# ----> 2 print(variable)
#
# NameError: name 'variable' is not defined

# %%
# %time print(2) # Ejecuta una funcion y el tiempo de ejecucion
# Out:
# 2
# CPU times: user 94 µs, sys: 0 ns, total: 94 µs
# Wall time: 99.4 µs

# %%
# %timeit print(2) # Ejecuta una funcion varias veces y el tiempo de ejecucion promedio

# %%
# %prun print(2) # Da detalles de la funcion
# Out:
# 2

# %%
variable = 2
string = "string"

# %%
# %who
# Out:
# string	 variable

# %%
# %who str
# %who int
# Out:
# string
# variable

# %%
# %who_ls
# Out:
# ['string', 'variable']

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# string     str     string
# variable   int     2

# %% [markdown]
# ### PYTHON

# %% [markdown]
# Console Output

# %%
print(1,2,3,4, sep='-', end = ' final')
# Out:
# 1-2-3-4 final

# %%
name = "Var"
print("KLK ", name )
# Out:
# KLK  Var

# %% [markdown]
# #### Numbers Int and Float
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Integers

# %%
#integers
#Arithmethic Operators
a = 2 + 2
b = 2-2
c = 2*2
d = 9 // 2 #division entera
e = 9 % 2 #resto
f = 2 **3 #potencia

print(a,b,c,d,e,f)
# Out:
# 4 0 4 4 1 8

# %%
#integer: Extended assignments

a = 2
a+=3
print(a)
a -=1
print(a)
a *=3
print(a)
a /=2
print(a)

a **=2
print(a)
# Out:
# 5
# 4
# 12
# 6.0
# 36.0

# %%
#Integer Casting
cadena = "3"
entero = int(cadena)
print(entero)
type(entero)
# Out:
# 3
# int

# %%
#Builtin functions
a = -1
b = abs(a) #abs
print(b)

a = 2
b = 3
c = pow(a,b)
print(c)
# Out:
# 1
# 8

# %% [markdown]
# float

# %%
a = 3.5 + 3.5
b = 3.2 - 0.2
c = 0.5 * 0.5
d = 0.5 / 2

e = 2.2 **2
print(a,b,c,d,e)
# Out:
# 7.0 3.0 0.25 0.25 4.840000000000001

# %%
a=1.5
a +=1
print(a)

a -= 1
print(a)

a *=2
print(a)

a /=2
print(a)

a **=2
print(a)
# Out:
# 2.5
# 1.5
# 3.0
# 1.5
# 2.25

# %%
#Casting
a = 2
print(type(a))

a = float(a)
print(type(a))

b = "2.5"
b = float(b)
b
# Out:
# <class 'int'>
# <class 'float'>
# 2.5

# %%
# Built functions
a=abs(-3.5)
a

b = pow(2.5,2)
print(b)

c = round(b)
print(c)
# Out:
# 6.25
# 6

# %% [markdown]
# #### Booleans - bool
# ![image.png](data:image/png;base64,...)

# %%
var = True
type(var)
# Out:
# bool

# %%
a = 3<2
print(a)

a = 3>=3
print(a)

c = 4==4
print(c)

d = 4!=4
print(d)
# Out:
# False
# True
# True
# False

# %%
# boolean operators OR, NOT
a = True and True
print(a)

b = True and False
print(b)

c = False and False
print(c)
# Out:
# True
# False
# False

# %%
for x in [0,1,0.0,1e-30,"f",""," ",[1,2],[],[ ],range(2), range(0)]:
  if x:
    print(x, "es True: ",bool(x))
  else:
    print(x, "es Falso: ", bool(x))
# Out:
# 0 es Falso:  False
# 1 es True:  True
# 0.0 es Falso:  False
# 1e-30 es True:  True
# f es True:  True
#  es Falso:  False
#   es True:  True
# [1, 2] es True:  True
# [] es Falso:  False
# [] es Falso:  False
# range(0, 2) es True:  True
# range(0, 0) es Falso:  False

# %% [markdown]
# #### Strings - str
#
# ![image.png](data:image/png;base64,...)

# %%
s = "Hola Mundo"
print(s[0])
print(s[-1])
print(s[0:4]) #no pilla el final
print(s[:4])
print(s[-4:])
print(s[::2])
print(s[::-1])
# Out:
# H
# o
# Hola
# Hola
# undo
# Hl ud
# odnuM aloH

# %% [markdown]
# **f-strings**

# %%
name = "Hernan"
print(f"mi nombre es {name}")
# Out:
# mi nombre es Hernan

# %%
from random import randint
a = randint(1,10)
print(f"El valor aleatorio es {a}")
# Out:
# El valor aleatorio es 5

# %% [markdown]
# **Strings Methods**
#
# ![image.png](data:image/png;base64,...)

# %%
s = "abcd"
s.count("a")
s.find("d")
# Out:
# 3

# %%
print(s.replace("a","b"))
print(s)
# Out:
# bbcd
# abcd

# %%
s = "hola mundo"
s.split(" ")
# Out:
# ['hola', 'mundo']

# %%
t = " mundial"
s.join(t)
# Out:
# ' hola mundomhola mundouhola mundonhola mundodhola mundoihola mundoahola mundol'
